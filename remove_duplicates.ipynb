# %%
import pandas as pd

# %%
df = pd.read_csv("mergedfile.csv")
# Out:
# C:\Users\Kipplouser1\AppData\Local\Temp\ipykernel_25868\2876150696.py:1: DtypeWarning: Columns (0,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("mergedfile.csv")

# %%
df
# Out:
#                  full_name first_name  last_name
# 0        stephanie rosario  stephanie    rosario  \
# 1              tony dotson       tony     dotson
# 2         heather wochnick    heather   wochnick
# 3            joseph manfre     joseph     manfre
# 4           j aaron hooper          j     hooper
# ...                    ...        ...        ...
# 5202698                NaN        don   mcmillan
# 5202699                NaN    dievina  navarrete
# 5202700                NaN         al  grabowski
# 5202701                NaN   jonathan      gibbs
# 5202702                NaN      bruce     coombs
#
#                                        linkedin_url
# 0                  linkedin.com/in/stephanierosario  \
# 1               linkedin.com/in/tony-dotson-2b76908
# 2         linkedin.com/in/heather-wochnick-32010858
# 3            linkedin.com/in/joseph-manfre-0092bb10
# 4            linkedin.com/in/j-aaron-hooper-7128393
# ...                                             ...
# ...

# %%
# Check Length of unique linkedin URLs
len(df['linkedin_url'].unique())
# Out:
# 3392954

# %%
# Length of all linkedin URLs
len(df['linkedin_url'])
# Out:
# 5202703

# %%
# Drop duplicates in the "linkedin_url" column
df.drop_duplicates(subset=['linkedin_url'], keep='first')
# Out:
#                  full_name first_name last_name
# 0        stephanie rosario  stephanie   rosario  \
# 1              tony dotson       tony    dotson
# 2         heather wochnick    heather  wochnick
# 3            joseph manfre     joseph    manfre
# 4           j aaron hooper          j    hooper
# ...                    ...        ...       ...
# 4846791                NaN   rochelle     tramp
# 4846792                NaN   veronica   herrera
# 4846793                NaN    chantel     brown
# 4846794                NaN    kenneth     scott
# 4846795                NaN      david     munos
#
#                                           linkedin_url
# 0                     linkedin.com/in/stephanierosario  \
# 1                  linkedin.com/in/tony-dotson-2b76908
# 2            linkedin.com/in/heather-wochnick-32010858
# 3               linkedin.com/in/joseph-manfre-0092bb10
# 4               linkedin.com/in/j-aaron-hooper-7128393
# ...

# %%
df.to_csv("merged_no_duplicates.csv")
